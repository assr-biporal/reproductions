# %%
import brian2
import brian2.units
import brian2.parsing.expressions
import brian2.sympytools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-f5277a7d144c> in <module>
#       2 import brian2.units
#       3 import brian2.parsing.expressions
# ----> 4 import brian2.sympytools
#
# ModuleNotFoundError: No module named 'brian2.sympytools'

# %%
brian2.parsing.sympytools.str_to_sympy('25*nS')
# Out:
# 25000.0*nS

# %%
brian2.units.Quantity(25, brian2.ms)
# Out:
# 25. * msecond

# %%
brian2.parsing.expressions._get_value_from_expression('10*ms',{})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-3d9d242b73a8> in <module>
# ----> 1 brian2.parsing.expressions._get_value_from_expression('10*ms',{})
#
# ~/.local/lib/python3.6/site-packages/brian2/parsing/expressions.py in _get_value_from_expression(expr, variables)
#     163         op = expr.op.__class__.__name__
#     164         left = _get_value_from_expression(expr.left, variables)
# --> 165         right = _get_value_from_expression(expr.right, variables)
#     166         if op == 'Add' or op == 'Sub':
#     167             v = left + right
#
# ~/.local/lib/python3.6/site-packages/brian2/parsing/expressions.py in _get_value_from_expression(expr, variables)
#     139             return 1.0 if name == 'True' else 0.0
#     140         else:
# --> 141             raise ValueError('Unknown identifier %s' % name)
# ...

# %%
10*brian2.ms.with_dimensions()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-1d708749e2f1> in <module>
# ----> 1 10*brian2.ms.with_dimensions()
#
# TypeError: with_dimensions() missing 1 required positional argument: 'value'

# %%
import brian2
eval('10*nS', brian2.core.namespace.DEFAULT_UNITS)
# Out:
# 10. * nsiemens
